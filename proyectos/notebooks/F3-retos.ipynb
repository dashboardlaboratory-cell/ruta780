# %% [markdown]
# # Retos — Fase 3Series de tiempo. Regla: **sin mirar la lección**.No borres los intentos fallidos. Anota el error debajo — el viernes se repasa.`uv run jupyter lab`

# %% [markdown]
# ## Series 1 — Descomposición: tendencia, estacionalidad y residuo

# %% [markdown]
# **1.** Descomponer la misma serie con $m$ igual al periodo verdadero, a la mitad y al doble, y anotar qué le pasa al perfil estacional en cada caso

# %%
# Descomponer la misma serie con m igual al periodo verdadero, a la mitad y
# al doble, y anotar qué le pasa al perfil estacional en cada caso.
# Relacionarlo con la Proposición 1.4a: ¿qué periodos se anulan con cada
# elección?

# %% [markdown]
# **2.** Construir una serie cuyo perfil estacional **cambie** a la mitad del recorrido —por ejemplo, que se duplique su amplitud— y descomponerla con el método clásico

# %%
# Construir una serie cuyo perfil estacional cambie a la mitad del recorrido
# —por ejemplo, que se duplique su amplitud— y descomponerla con el método
# clásico. Medir el residuo antes y después del cambio, y anotar qué señal
# habría avisado de que el perfil no es fijo.

# %% [markdown]
# **3.** Aplicar la descomposición aditiva a una serie claramente multiplicativa y anotar en `50-Errores/` qué forma toma el residuo

# %%
# Aplicar la descomposición aditiva a una serie claramente multiplicativa y
# anotar en 50-Errores/ qué forma toma el residuo. Contrastarla con la del
# mismo dato descompuesto sobre su logaritmo, y describir el patrón que
# delata la elección equivocada.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Series 2 — Estacionariedad y sus pruebas: ADF y KPSS

# %% [markdown]
# **1.** Repetir la simulación de los cuantiles del ADF con $n=50$, $n=250$ y $n=1000$, y anotar cómo se mueve el valor crítico del $5\,\%$ con la longitud de la serie

# %%
# Repetir la simulación de los cuantiles del ADF con n=50, n=250 y n=1000, y
# anotar cómo se mueve el valor crítico del 5,% con la longitud de la serie.
# Contrastar con el número único que traen las tablas de un solo valor.

# %% [markdown]
# **2.** Tomar una serie propia con tendencia clara, aplicarle los tres remedios de la sección 5 y clasificarla con las dos pruebas

# %%
# Tomar una serie propia con tendencia clara, aplicarle los tres remedios de
# la sección 5 y clasificarla con las dos pruebas. Anotar en qué celda de la
# tabla de cuatro filas cae, y qué conclusión se sostiene.

# %% [markdown]
# **3.** Construir dos paseos aleatorios independientes, regresar uno sobre otro y **dibujar los dos juntos** con el $R^2$ en el título

# %%
# Construir dos paseos aleatorios independientes, regresar uno sobre otro y
# dibujar los dos juntos con el R^2 en el título. Guardar el dibujo en
# 50-Errores/ como recordatorio de que un ajuste alto sobre series en nivel
# no prueba nada.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Series 3 — Autocorrelación: ACF y PACF

# %% [markdown]
# **1.** Simular un $\text{ARMA}(1,1)$ y dibujar su ACF y su PACF

# %%
# Simular un ARMA(1,1) y dibujar su ACF y su PACF. Comprobar que ninguna de
# las dos se corta y anotar qué órdenes se habrían adivinado mirando solo el
# dibujo.

# %% [markdown]
# **2.** Tomar la serie de la lección 1 —tendencia, estacionalidad y ruido—, dibujar su ACF antes y después de la descomposición, y anotar qué pico sobrevive y qué significa

# %%
# Tomar la serie de la lección 1 —tendencia, estacionalidad y ruido—,
# dibujar su ACF antes y después de la descomposición, y anotar qué pico
# sobrevive y qué significa.

# %% [markdown]
# **3.** Comprobar la Proposición 3.2 sobre una serie propia sumando todas las autocorrelaciones hasta $n-1$, y anotar en `50-Errores/` qué pasa si la suma se corta en el retardo $20$ como hacen los dibujos habituales

# %%
# Comprobar la Proposición 3.2 sobre una serie propia sumando todas las
# autocorrelaciones hasta n-1, y anotar en 50-Errores/ qué pasa si la suma
# se corta en el retardo 20 como hacen los dibujos habituales.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Series 4 — ARIMA y SARIMA, derivados

# %% [markdown]
# **1.** Ajustar un $\text{AR}(p)$ por Yule-Walker con $p$ de uno a seis sobre una serie simulada de orden dos, y anotar qué pasa con los coeficientes sobrantes

# %%
# Ajustar un AR(p) por Yule-Walker con p de uno a seis sobre una serie
# simulada de orden dos, y anotar qué pasa con los coeficientes sobrantes.
# Contrastar con lo que dice la PACF de la lección 3.

# %% [markdown]
# **2.** Simular un $\text{ARMA}(1,1)$ con $\theta$ cerca de $-\varphi$ —por ejemplo $\varphi=0{,}7$ y $\theta=-0{,}65$— y medir cuántas observaciones hacen falta para que su ACF se distinga de la del ruido blanco

# %%
# Simular un ARMA(1,1) con θ cerca de -varphi —por ejemplo varphi=0{,}7 y
# θ=-0{,}65— y medir cuántas observaciones hacen falta para que su ACF se
# distinga de la del ruido blanco. Anotar la cifra: es la distancia real
# entre la Proposición 4.3 y la práctica.

# %% [markdown]
# **3.** Dibujar el abanico de pronóstico de un $\text{AR}(1)$ y de un paseo aleatorio sobre los mismos datos y guardar la figura en `50-Errores/` con la anchura a cincuenta pasos anotada en el título

# %%
# Dibujar el abanico de pronóstico de un AR(1) y de un paseo aleatorio sobre
# los mismos datos y guardar la figura en 50-Errores/ con la anchura a
# cincuenta pasos anotada en el título.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Series 5 — Suavizado exponencial y modelos de estado

# %% [markdown]
# **1.** Ajustar $\alpha$ por mínimos cuadrados sobre el error a un paso, en una malla de cien valores, y dibujar la curva del error contra $\alpha$

# %%
# Ajustar α por mínimos cuadrados sobre el error a un paso, en una malla de
# cien valores, y dibujar la curva del error contra α. Anotar si el mínimo
# cae en el interior o en un borde, y qué significaría cada caso.

# %% [markdown]
# **2.** Simular un modelo de nivel local con $q$ conocido, filtrarlo con tres factores distintos —el correcto y dos equivocados— y medir el error contra el nivel verdadero

# %%
# Simular un modelo de nivel local con q conocido, filtrarlo con tres
# factores distintos —el correcto y dos equivocados— y medir el error contra
# el nivel verdadero. Anotar cuánto cuesta equivocarse en cada sentido.

# %% [markdown]
# **3.** Aplicar el suavizado a una serie con un salto de nivel claro y anotar en `50-Errores/` cuántos instantes tarda en alcanzarlo con $\alpha=0{,}1$ y con $\alpha=0{,}5$

# %%
# Aplicar el suavizado a una serie con un salto de nivel claro y anotar en
# 50-Errores/ cuántos instantes tarda en alcanzarlo con α=0{,}1 y con
# α=0{,}5. Relacionarlo con la semivida de la Proposición 5.6.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Series 6 — Features de calendario: feriados, promociones y eventos

# %% [markdown]
# **1.** Construir la matriz de diseño con indicadores y con armónicos para $s=7$ y comprobar la Proposición 6.3 a mano, escribiendo el cambio de base explícito entre las dos

# %%
# Construir la matriz de diseño con indicadores y con armónicos para s=7 y
# comprobar la Proposición 6.3 a mano, escribiendo el cambio de base
# explícito entre las dos. Anotar cuánto ocupa la matriz de cambio.

# %% [markdown]
# **2.** Simular un evento cuya ventana dure tres observaciones y ajustarlo con un solo indicador del día central

# %%
# Simular un evento cuya ventana dure tres observaciones y ajustarlo con un
# solo indicador del día central. Medir qué fracción del efecto se recupera
# y compararla con la dilución de la Proposición 6.6.

# %% [markdown]
# **3.** Tomar una serie con estacionalidad anual y una punta conocida, ajustarla con $K$ de uno a diez, y dibujar el error contra $K$

# %%
# Tomar una serie con estacionalidad anual y una punta conocida, ajustarla
# con K de uno a diez, y dibujar el error contra K. Guardar el dibujo en
# 50-Errores/ anotando dónde deja de mejorar.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Series 7 — Validación temporal: backtesting sin fuga

# %% [markdown]
# **1.** Montar un backtesting de origen móvil sobre una serie propia, con ventana expandible y deslizante, y comparar los errores

# %%
# Montar un backtesting de origen móvil sobre una serie propia, con ventana
# expandible y deslizante, y comparar los errores. Anotar si la deslizante
# gana, y a partir de qué longitud de ventana.

# %% [markdown]
# **2.** Repetir la medición de la Proposición 7.4 con una columna de rellenado de faltantes por interpolación lineal

# %%
# Repetir la medición de la Proposición 7.4 con una columna de rellenado de
# faltantes por interpolación lineal. Anotar cuánto R^2 regala sobre ruido
# blanco y por qué.

# %% [markdown]
# **3.** Evaluar el mismo modelo con $k$-fold y con origen móvil sobre una serie con tendencia clara, y guardar en `50-Errores/` los dos números junto con la frase que los distingue: qué pregunta contesta cada uno

# %%
# Evaluar el mismo modelo con k-fold y con origen móvil sobre una serie con
# tendencia clara, y guardar en 50-Errores/ los dos números junto con la
# frase que los distingue: qué pregunta contesta cada uno.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Series 8 — Forecasting con gradient boosting

# %% [markdown]
# **1.** Añadir a la matriz de retardos las columnas de calendario de la lección 6 y repetir la comparación pareada contra el modelo lineal

# %%
# Añadir a la matriz de retardos las columnas de calendario de la lección 6
# y repetir la comparación pareada contra el modelo lineal. Anotar si el
# boosting pasa a ganar y en qué horizontes.

# %% [markdown]
# **2.** Repetir el experimento de la Proposición 8.2 con una serie sin tendencia pero con un cambio de nivel a la mitad

# %%
# Repetir el experimento de la Proposición 8.2 con una serie sin tendencia
# pero con un cambio de nivel a la mitad. Anotar qué hace el pronóstico al
# llegar al nivel nuevo y por qué.

# %% [markdown]
# **3.** Ajustar la profundidad de los árboles de uno a seis y dibujar el error de backtesting contra la profundidad

# %%
# Ajustar la profundidad de los árboles de uno a seis y dibujar el error de
# backtesting contra la profundidad. Guardar el dibujo en 50-Errores/
# anotando dónde está el mínimo y si es distinguible del vecino.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Series 9 — Prophet: qué hace por dentro

# %% [markdown]
# **1.** Ajustar la tendencia por tramos con $\lambda$ en una malla y dibujar el número de puntos de cambio activos contra $\lambda$

# %%
# Ajustar la tendencia por tramos con λ en una malla y dibujar el número de
# puntos de cambio activos contra λ. Anotar dónde está el codo y compararlo
# con la traza del lasso de Machine Learning 9.

# %% [markdown]
# **2.** Añadir la estacionalidad de armónicos al diseño y comprobar sobre una serie con una punta de una sola posición qué parte de esa punta queda sin explicar

# %%
# Añadir la estacionalidad de armónicos al diseño y comprobar sobre una
# serie con una punta de una sola posición qué parte de esa punta queda sin
# explicar. Relacionarlo con la Proposición 6.5.

# %% [markdown]
# **3.** Comparar este modelo contra el ARIMA de la lección 4 sobre la misma serie, con el backtesting pareado de la lección 8, y guardar en `50-Errores/` el cociente obtenido y si es distinguible de cero

# %%
# Comparar este modelo contra el ARIMA de la lección 4 sobre la misma serie,
# con el backtesting pareado de la lección 8, y guardar en 50-Errores/ el
# cociente obtenido y si es distinguible de cero.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Series 10 — Forecasts jerárquicos y reconciliación

# %% [markdown]
# **1.** Construir una jerarquía de tres niveles y comprobar la Proposición 10.5 sobre ella

# %%
# Construir una jerarquía de tres niveles y comprobar la Proposición 10.5
# sobre ella. Anotar si aparece algún caso por encima de la diagonal y por
# qué no puede aparecer.

# %% [markdown]
# **2.** Estimar $\Sigma$ con un backtesting de la lección 7 en lugar de suponerla, y comparar la reconciliación ponderada resultante con la de mínimos cuadrados

# %%
# Estimar Σ con un backtesting de la lección 7 en lugar de suponerla, y
# comparar la reconciliación ponderada resultante con la de mínimos
# cuadrados. Anotar cuántos orígenes hacen falta para que la ponderada gane
# de forma distinguible.

# %% [markdown]
# **3.** Medir, serie a serie, cuánto empeora cada una al reconciliar, y guardar en `50-Errores/` el histograma junto con la mejora total

# %%
# Medir, serie a serie, cuánto empeora cada una al reconciliar, y guardar en
# 50-Errores/ el histograma junto con la mejora total. Anotar qué serie sale
# peor parada y si eso tiene sentido.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Series 11 — Evaluación: MAPE, MASE y por qué el promedio miente

# %% [markdown]
# **1.** Tomar los errores de un backtesting propio y calcular las cinco métricas de la Definición 11.1

# %%
# Tomar los errores de un backtesting propio y calcular las cinco métricas
# de la Definición 11.1. Anotar si ordenan igual a dos modelos, y si no,
# cuál cambia el orden.

# %% [markdown]
# **2.** Simular una cartera de series de escalas muy distintas y comprobar la Proposición 11.5 con sus números

# %%
# Simular una cartera de series de escalas muy distintas y comprobar la
# Proposición 11.5 con sus números. Anotar cuánto esfuerzo dirigiría cada
# métrica hacia la serie más pequeña.

# %% [markdown]
# **3.** Escribir la pérdida real de un problema concreto —con su coste de quedarse corto y de pasarse— y encontrar el pronóstico óptimo para ella

# %%
# Escribir la pérdida real de un problema concreto —con su coste de quedarse
# corto y de pasarse— y encontrar el pronóstico óptimo para ella. Guardar en
# 50-Errores/ la distancia entre ese óptimo y el que darían MAE y MAPE.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## ML 38 — Inicialización y funciones de activación

# %% [markdown]
# **1.** Entrenar la red de la Lección 37 arrancando todos los pesos iguales y con pesos distintos, y anotar cuántos valores distintos produce la capa oculta en cada caso y qué pérdida alcanza

# %%
# Entrenar la red de la Lección 37 arrancando todos los pesos iguales y con
# pesos distintos, y anotar cuántos valores distintos produce la capa oculta
# en cada caso y qué pérdida alcanza.

# %% [markdown]
# **2.** Medir la desviación típica de las activaciones por capa en una red de diez capas con tres escalas distintas, antes de entrenar

# %%
# Medir la desviación típica de las activaciones por capa en una red de diez
# capas con tres escalas distintas, antes de entrenar. Anotar cuál conserva
# la señal y comparar con 1/raíz de{n}.

# %% [markdown]
# **3.** Contar cuántas unidades de una capa no producen ningún valor positivo tras la primera pasada, variando el sesgo inicial

# %%
# Contar cuántas unidades de una capa no producen ningún valor positivo tras
# la primera pasada, variando el sesgo inicial. Guardar en 50-Errores/ el
# sesgo a partir del cual muere más de la mitad.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## ML 39 — Optimizadores: SGD, momentum y Adam, derivados

# %% [markdown]
# **1.** Escribir el descenso con paso fijo sobre una cuadrática de espectro elegido y comprobar la forma cerrada $(I-\eta A)^{k}$ para cinco pasos distintos, incluido uno que diverja

# %%
# Escribir el descenso con paso fijo sobre una cuadrática de espectro
# elegido y comprobar la forma cerrada (I-η A)^{k} para cinco pasos
# distintos, incluido uno que diverja. Anotar el paso máximo y el óptimo.

# %% [markdown]
# **2.** Escribir el impulso y medir cuántos pasos necesita para 1e-8 con $\kappa$ igual a 10, 100 y 1000

# %%
# Escribir el impulso y medir cuántos pasos necesita para 1e-8 con κ igual a
# 10, 100 y 1000. Comparar con (raíz de{κ}-1)/(raíz de{κ}+1).

# %% [markdown]
# **3.** Medir la meseta del paso fijo estocástico con tres pasos y tres tamaños de lote, y comprobar la predicción con la corrección $\tfrac{N-m}{N-1}$

# %%
# Medir la meseta del paso fijo estocástico con tres pasos y tres tamaños de
# lote, y comprobar la predicción con la corrección tfrac{N-m}{N-1}. Guardar
# en 50-Errores/ el caso en que la predicción falle y la razón.

# %% [markdown]
# **Qué me costó / qué aprendí:**
