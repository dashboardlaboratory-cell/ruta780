# %% [markdown]
# # Retos — Fase 5
#
# Inferencia causal. Regla: **sin mirar la lección**.
#
# No borres los intentos fallidos. Anota el error debajo — el viernes se repasa.
#
# `uv run jupyter lab`

# %% [markdown]
# ## Causal 1 — Resultados potenciales y el problema fundamental

# %% [markdown]
# **1.** Simular una población con los dos resultados potenciales conocidos y una asignación que dependa de una variable previa

# %%
# Simular una población con los dos resultados potenciales conocidos y una
# asignación que dependa de una variable previa. Comprobar la identidad
# diferencia = ATT + sesgo y anotar qué fracción de lo medido es sesgo.

# %% [markdown]
# **2.** Enumerar todas las asignaciones de $m$ tratados entre $n$ para $n$ igual a 8, 10 y 12, y comprobar que la media de las estimaciones es el ATE

# %%
# Enumerar todas las asignaciones de m tratados entre n para n igual a 8, 10
# y 12, y comprobar que la media de las estimaciones es el ATE. Anotar la
# desviación típica en cada caso.

# %% [markdown]
# **3.** Sobre datos con el tratamiento asignado al azar, ajustar por una variable medida **después** del tratamiento y medir cuánto se desvía la estimación

# %%
# Sobre datos con el tratamiento asignado al azar, ajustar por una variable
# medida después del tratamiento y medir cuánto se desvía la estimación.
# Guardar en 50-Errores/ el caso en que el signo cambie y qué variable lo
# provocó.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Causal 2 — DAGs y criterio de puerta trasera

# %% [markdown]
# **1.** Simular las tres estructuras de tres variables y medir la correlación de $A$ y $C$ antes y después de fijar $B$, por cuartiles

# %%
# Simular las tres estructuras de tres variables y medir la correlación de A
# y C antes y después de fijar B, por cuartiles. Anotar cuál de las tres
# cambia de dirección.

# %% [markdown]
# **2.** Escribir el algoritmo de d-separación sobre un grafo propio de cinco o seis nodos y comprobarlo contra las correlaciones parciales en todos los pares y subconjuntos

# %%
# Escribir el algoritmo de d-separación sobre un grafo propio de cinco o
# seis nodos y comprobarlo contra las correlaciones parciales en todos los
# pares y subconjuntos. Anotar cuántos casos hay y si alguno discrepa.

# %% [markdown]
# **3.** Construir un grafo con una causa común no observada y probar todos los subconjuntos de lo observable

# %%
# Construir un grafo con una causa común no observada y probar todos los
# subconjuntos de lo observable. Guardar en 50-Errores/ el subconjunto que
# más se acerque al efecto verdadero sin cumplir el criterio, y por qué se
# acerca.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Causal 16 — Metalearners: S, T y X desde cero

# %% [markdown]
# **1.** Escribir los tres learners sobre una población simulada propia y medir, para cuatro proporciones tratadas, el ECM y el efecto que logra la política de cada uno

# %%
# Escribir los tres learners sobre una población simulada propia y medir,
# para cuatro proporciones tratadas, el ECM y el efecto que logra la
# política de cada uno. Anotar en qué filas los dos criterios discrepan.

# %% [markdown]
# **2.** Repetir el S-learner variando el peso de la línea base y anotar la importancia de la columna del tratamiento y la desviación típica del efecto estimado

# %%
# Repetir el S-learner variando el peso de la línea base y anotar la
# importancia de la columna del tratamiento y la desviación típica del
# efecto estimado. Comprobar que el encogimiento va siempre hacia cero.

# %% [markdown]
# **3.** Meter un confusor no observado con tres fuerzas y medir cuánto se desplaza el ATE estimado

# %%
# Meter un confusor no observado con tres fuerzas y medir cuánto se desplaza
# el ATE estimado. Guardar en 50-Errores/ la fuerza a partir de la cual la
# política deja de ser mejor que tratar a todos.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Causal 17 — Double machine learning y Frisch-Waugh-Lovell

# %% [markdown]
# **1.** Implementar los dos caminos de Frisch-Waugh-Lovell sobre datos propios y comprobar que coinciden

# %%
# Implementar los dos caminos de Frisch-Waugh-Lovell sobre datos propios y
# comprobar que coinciden. Medir además el error típico residualizando los
# dos y solo T, y anotar el cociente.

# %% [markdown]
# **2.** Construir una confusión no lineal y comparar el estimador lineal con uno que residualice con un modelo flexible, barriendo lo torcida que sea

# %%
# Construir una confusión no lineal y comparar el estimador lineal con uno
# que residualice con un modelo flexible, barriendo lo torcida que sea.
# Anotar a partir de qué punto el lineal deja de servir.

# %% [markdown]
# **3.** Barrer la flexibilidad del modelo auxiliar con y sin cross-fitting, y anotar dónde está el mínimo de cada curva

# %%
# Barrer la flexibilidad del modelo auxiliar con y sin cross-fitting, y
# anotar dónde está el mínimo de cada curva. Guardar en 50-Errores/ el caso
# en que el cross-fitting no mejore nada y la razón.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Causal 18 — El R-learner y el R-score: elegir entre modelos de efecto

# %% [markdown]
# **1.** Comprobar la descomposición de Robinson sobre una población propia con las auxiliares exactas, y anotar la desviación de lo que sobra y su $R^2$ contra $X$ y contra $T$

# %%
# Comprobar la descomposición de Robinson sobre una población propia con las
# auxiliares exactas, y anotar la desviación de lo que sobra y su R^2 contra
# X y contra T.

# %% [markdown]
# **2.** Implementar el R-learner y compararlo con los tres metalearners por ECM contra $\tau$ y por R-score

# %%
# Implementar el R-learner y compararlo con los tres metalearners por ECM
# contra τ y por R-score. Anotar si los dos rankings coinciden.

# %% [markdown]
# **3.** Encoger el ruido del tratamiento hasta que el R-score deje de distinguir, midiendo la diferencia en errores típicos

# %%
# Encoger el ruido del tratamiento hasta que el R-score deje de distinguir,
# midiendo la diferencia en errores típicos. Guardar en 50-Errores/ el punto
# en que baja de 2 y cuánta muestra de prueba haría falta allí.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Causal 19 — Árboles causales honestos y el bosque causal

# %% [markdown]
# **1.** Construir una población donde el resultado y el efecto los muevan variables distintas, ajustar un árbol de regresión corriente y anotar la importancia que le da a la variable del efecto

# %%
# Construir una población donde el resultado y el efecto los muevan
# variables distintas, ajustar un árbol de regresión corriente y anotar la
# importancia que le da a la variable del efecto.

# %% [markdown]
# **2.** Escribir el criterio de corte causal y comparar, sobre la raíz, su puntuación con la del criterio del resultado para cada variable

# %%
# Escribir el criterio de corte causal y comparar, sobre la raíz, su
# puntuación con la del criterio del resultado para cada variable. Anotar
# cuál elige cada uno.

# %% [markdown]
# **3.** Con un efecto **constante**, medir la dispersión que cada árbol atribuye a los efectos por hoja y cuántas hojas declaran un efecto distinto con un intervalo al 95 %

# %%
# Con un efecto constante, medir la dispersión que cada árbol atribuye a los
# efectos por hoja y cuántas hojas declaran un efecto distinto con un
# intervalo al 95 %. Guardar en 50-Errores/ la tasa de falso hallazgo del
# árbol adaptativo.

# %% [markdown]
# **Qué me costó / qué aprendí:**

# %% [markdown]
# ## Causal 21 — Evaluación de políticas: el estimador doblemente robusto

# %% [markdown]
# **1.** Implementar los tres estimadores del valor de una política sobre un experimento simulado con los dos resultados potenciales conocidos, y comparar sus errores típicos sobre cuatro políticas

# %%
# Implementar los tres estimadores del valor de una política sobre un
# experimento simulado con los dos resultados potenciales conocidos, y
# comparar sus errores típicos sobre cuatro políticas.

# %% [markdown]
# **2.** Romper el modelo del resultado y la propensión por separado y a la vez, y anotar el error de cada estimador en las cuatro combinaciones

# %%
# Romper el modelo del resultado y la propensión por separado y a la vez, y
# anotar el error de cada estimador en las cuatro combinaciones.

# %% [markdown]
# **3.** Montar un experimento de tres o cuatro brazos, construir la política que da a cada unidad el brazo con mayor resultado predicho y medir cuánto gana al mejor brazo único, con su error típico

# %%
# Montar un experimento de tres o cuatro brazos, construir la política que
# da a cada unidad el brazo con mayor resultado predicho y medir cuánto gana
# al mejor brazo único, con su error típico. Guardar en 50-Errores/ el caso
# en que la ventaja no supere los dos errores típicos.

# %% [markdown]
# **Qué me costó / qué aprendí:**
